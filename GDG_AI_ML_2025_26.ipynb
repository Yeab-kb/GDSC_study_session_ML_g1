# %% [markdown]
# <a href="https://colab.research.google.com/github/Yeab-kb/GDSC_study_session_ML_g1/blob/main/GDG_AI_ML_2025_26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import numpy as np

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
import matplotlib.pyplot as plt

# %%
from sklearn.model_selection import train_test_split

# %%
data = { "hours_studied": [21, 33, 43, 52],
        "test_scored": [60, 70, 85, 90]}

df = pd.DataFrame(data)

# %%
x = df[["hours_studied"]]
y = df["test_scored"]

x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2,random_state=42)

# %%
model = LinearRegression()
model.fit(x_train, y_train)

y_pred = model.predict(x_test)

mse= mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)

print("model coefficient(slope):", model.coef_[0])
print("model intercept:", model.intercept_)
print("mean squared error (MSE):" , mse)
print("mean absolute error (MAE):" , mae)

plt.scatter(x,y)
plt.plot(x, model.predict(x), linewidth=2)
plt.xlabel("study hours")
plt.ylabel("test score")
plt.title("linear regression: study hours vs test score")
plt.show()
# Out:
# model coefficient(slope): 0.9993446920052425
# model intercept: 39.69200524246396
# mean squared error (MSE): 7.130929764381098
# mean absolute error (MAE): 2.6703800786369527
